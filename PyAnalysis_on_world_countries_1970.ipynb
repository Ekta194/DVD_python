# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
countries_df = pd.read_csv ('Countries_world_1970 .csv')

# %%
countries_df
# Out:
#                    Entity  indiv_libs_vdem_owid  electdem_vdem_owid  \
# 0             Afghanistan                 0.266               0.160
# 1                 Albania                 0.006               0.173
# 2                 Algeria                 0.428               0.084
# 3                  Angola                 0.024               0.010
# 4               Argentina                 0.354               0.105
# ..                    ...                   ...                 ...
# 177  United Arab Emirates                   NaN                 NaN
# 178          Bahamas, The                   NaN                 NaN
# 179                Belize                   NaN                 NaN
# 180     Brunei Darussalam                   NaN                 NaN
# 181            Montenegro                   NaN                 NaN
#
#      libdem_vdem_owid             Countries  Economic.Freedom.Summary.Index  \
# ...

# %%
countries_df.head(10)
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
# 5      Armenia                 0.094               0.102             0.024
# 6    Australia                 0.980               0.860             0.807
# 7      Austria                 0.949               0.843             0.728
# 8   Azerbaijan                 0.094               0.102             0.024
# 9      Bahrain                 0.449               0.024               NaN
#
#     Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0         NaN                        5.506573                6.393604
# ...

# %%
plt.scatter(countries_df['indiv_libs_vdem_owid'],countries_df['electdem_vdem_owid'])

# %%
countries_df["index average"] = (countries_df["indiv_libs_vdem_owid"]+countries_df["electdem_vdem_owid"]+countries_df["libdem_vdem_owid"])

# %%
countries_df["index average"].head(10)
# Out:
# 0    0.530
# 1    0.234
# 2    0.577
# 3    0.069
# 4    0.545
# 5    0.220
# 6    2.647
# 7    2.520
# 8    0.220
# 9      NaN
# Name: index average, dtype: float64

# %%
regressor = LinearRegression()

# %%
X = countries_df["indiv_libs_vdem_owid"].values.reshape(-1, 1)
y = countries_df["libdem_vdem_owid"].values.reshape(-1, 1)

regressor.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 X = countries_df["indiv_libs_vdem_owid"].values.reshape(-1, 1)
#       2 y = countries_df["libdem_vdem_owid"].values.reshape(-1, 1)
# ----> 4 regressor.fit(X, y)
#
# File C:\ProgramData\anaconda6\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %%
countries_df.head()
# Out:
#         Entity  indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# 0  Afghanistan                 0.266               0.160             0.104
# 1      Albania                 0.006               0.173             0.055
# 2      Algeria                 0.428               0.084             0.065
# 3       Angola                 0.024               0.010             0.035
# 4    Argentina                 0.354               0.105             0.086
#
#    Countries  Economic.Freedom.Summary.Index  Government.consumption  \
# 0        NaN                        5.506573                6.393604
# 1    Albania                        3.713222                3.170575
# 2    Algeria                        4.680000                5.540000
# 3     Angola                        4.547754                6.109553
# 4  Argentina                        5.980000                7.930000
#
#    Transfers.and.subsidies  Government.investment  State.ownership.of.assets  \
# ...

# %%
countries_df.tail()
# Out:
#                    Entity  indiv_libs_vdem_owid  electdem_vdem_owid  \
# 177  United Arab Emirates                   NaN                 NaN
# 178          Bahamas, The                   NaN                 NaN
# 179                Belize                   NaN                 NaN
# 180     Brunei Darussalam                   NaN                 NaN
# 181            Montenegro                   NaN                 NaN
#
#      libdem_vdem_owid             Countries  Economic.Freedom.Summary.Index  \
# 177               NaN  United Arab Emirates                        5.318299
# 178               NaN          Bahamas, The                        6.444528
# 179               NaN                Belize                        6.552629
# 180               NaN     Brunei Darussalam                        5.429512
# 181               NaN            Montenegro                        5.034850
#
#      Government.consumption  Transfers.and.subsidies  Government.investment  \
# ...

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 44 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
countries_df.describe()
# Out:
#        indiv_libs_vdem_owid  electdem_vdem_owid  libdem_vdem_owid  \
# count            177.000000          177.000000        175.000000
# mean               0.433633            0.271169          0.205794
# std                0.308818            0.255504          0.239538
# min                0.003000            0.010000          0.011000
# 25%                0.135000            0.102000          0.044500
# 50%                0.373000            0.169000          0.096000
# 75%                0.682000            0.322000          0.244000
# max                0.992000            0.905000          0.879000
#
#        Economic.Freedom.Summary.Index  Government.consumption  \
# count                      182.000000              182.000000
# mean                         5.497105                6.397742
# std                          0.990792                1.631789
# min                          3.400000                0.050000
# ...

# %%
countries_df[judical.independence].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 countries_df[judical.independence].describe()
#
# NameError: name 'judical' is not defined

# %%
countries_df.shape
# Out:
# (182, 44)

# %%
countries_df.shape[0]
# Out:
# 182

# %%
countries_df.shape[1]
# Out:
# 44

# %%
current_raws = countries_df.shape[0]
current_columns = countries_df.shape[1]

# %%
current_raws
# Out:
# 182

# %%
current_columns
# Out:
# 44

# %%
countries_df.columns[5]
# Out:
# 'Economic.Freedom.Summary.Index'

# %%
countries_df.value_counts('indiv_libs_vdem_owid')
# Out:
# indiv_libs_vdem_owid
# 0.094    15
# 0.617     5
# 0.118     3
# 0.983     2
# 0.982     2
#          ..
# 0.260     1
# 0.246     1
# 0.242     1
# 0.232     1
# 0.992     1
# Length: 142, dtype: int64

# %%
countries_df.value_counts('Regime_type')
# Out:
# Regime_type
# Single-party rule                 41
# Democracy                         39
# Military rule                     34
# unknown                           25
# Personalist rule                  20
# Monarchy                          13
# Multi-party authoritarian rule     6
# Other oligarchy                    4
# dtype: int64

# %%
countries_df.value_counts('Regime_type')[5]
# Out:
# 13

# %%
grouped_by_regime = countries_df.groupby('Regime_type')

# %%
grouped_by_regime

# %%
print(grouped_by_regime)

# %%
grouped_by_regime.describe()
# Out:
#                                indiv_libs_vdem_owid                      \
#                                               count      mean       std
# Regime_type
# Democracy                                      39.0  0.841462  0.204599
# Military rule                                  34.0  0.272853  0.142028
# Monarchy                                       13.0  0.357462  0.190659
# Multi-party authoritarian rule                  6.0  0.609000  0.210711
# Other oligarchy                                 4.0  0.218250  0.216649
# Personalist rule                               20.0  0.390350  0.227198
# Single-party rule                              40.0  0.264850  0.209088
# unknown                                        21.0  0.337333  0.305038
#
#                                                                        \
#                                   min     25%     50%      75%    max
# Regime_type
# Democracy                       0.049  0.7910  0.9090  0.97250  0.992
# ...

# %%
grouped_by_regime['indiv_libs_vdem_owid'].describe()
# Out:
#                                 count      mean       std    min     25%  \
# Regime_type
# Democracy                        39.0  0.841462  0.204599  0.049  0.7910
# Military rule                    34.0  0.272853  0.142028  0.078  0.1435
# Monarchy                         13.0  0.357462  0.190659  0.118  0.2020
# Multi-party authoritarian rule    6.0  0.609000  0.210711  0.336  0.4780
# Other oligarchy                   4.0  0.218250  0.216649  0.099  0.1095
# Personalist rule                 20.0  0.390350  0.227198  0.003  0.2530
# Single-party rule                40.0  0.264850  0.209088  0.006  0.0940
# unknown                          21.0  0.337333  0.305038  0.012  0.0940
#
#                                    50%      75%    max
# Regime_type
# Democracy                       0.9090  0.97250  0.992
# Military rule                   0.2440  0.37300  0.592
# Monarchy                        0.3800  0.40200  0.726
# Multi-party authoritarian rule  0.5795  0.78150  0.866
# ...

# %%
grouped_by_regime['Freedom.to.trade.Internationally'].describe()
# Out:
#                                 count      mean       std       min       25%  \
# Regime_type
# Democracy                        39.0  5.830230  2.642006  0.080000  4.375000
# Military rule                    34.0  4.259477  1.673841  0.440000  3.179889
# Monarchy                         13.0  4.996310  2.195434  0.480000  4.209222
# Multi-party authoritarian rule    6.0  5.599264  1.925010  2.396795  4.848924
# Other oligarchy                   4.0  5.215336  1.684225  3.284083  4.068656
# Personalist rule                 20.0  4.729322  1.161081  2.150000  4.412475
# Single-party rule                41.0  2.787732  1.544485 -0.231561  1.800364
# unknown                          25.0  4.587649  1.410757  1.737372  3.937596
#
#                                      50%       75%       max
# Regime_type
# Democracy                       6.470000  7.500000  9.960000
# Military rule                   4.327101  5.178970  8.620000
# ...

# %%
grouped_by_regime.head()
# Out:
#                      Entity  indiv_libs_vdem_owid  electdem_vdem_owid  \
# 0               Afghanistan                 0.266               0.160
# 1                   Albania                 0.006               0.173
# 2                   Algeria                 0.428               0.084
# 3                    Angola                 0.024               0.010
# 4                 Argentina                 0.354               0.105
# 5                   Armenia                 0.094               0.102
# 6                 Australia                 0.980               0.860
# 7                   Austria                 0.949               0.843
# 8                Azerbaijan                 0.094               0.102
# 9                   Bahrain                 0.449               0.024
# 10               Bangladesh                 0.383               0.168
# 11                 Barbados                 0.904               0.726
# ...

# %%
#2nd way to code for groupby or Regime_type
countries_df.groupby('Regime_type')['Freedom.to.trade.Internationally'].describe()
# Out:
#                                 count      mean       std       min       25%  \
# Regime_type
# Democracy                        39.0  5.830230  2.642006  0.080000  4.375000
# Military rule                    34.0  4.259477  1.673841  0.440000  3.179889
# Monarchy                         13.0  4.996310  2.195434  0.480000  4.209222
# Multi-party authoritarian rule    6.0  5.599264  1.925010  2.396795  4.848924
# Other oligarchy                   4.0  5.215336  1.684225  3.284083  4.068656
# Personalist rule                 20.0  4.729322  1.161081  2.150000  4.412475
# Single-party rule                41.0  2.787732  1.544485 -0.231561  1.800364
# unknown                          25.0  4.587649  1.410757  1.737372  3.937596
#
#                                      50%       75%       max
# Regime_type
# Democracy                       6.470000  7.500000  9.960000
# Military rule                   4.327101  5.178970  8.620000
# ...

# %%
 countries_df['libdem_vdem_owid_replacemean'] = countries_df['libdem_vdem_owid'].fillna(countries_df['libdem_vdem_owid'].mean())

# %%
countries_df['libdem_vdem_owid'].head(10)
# Out:
# 0    0.104
# 1    0.055
# 2    0.065
# 3    0.035
# 4    0.086
# 5    0.024
# 6    0.807
# 7    0.728
# 8    0.024
# 9      NaN
# Name: libdem_vdem_owid, dtype: float64

# %%
countries_df['libdem_vdem_owid_replacemean'].head(10)
# Out:
# 0    0.104000
# 1    0.055000
# 2    0.065000
# 3    0.035000
# 4    0.086000
# 5    0.024000
# 6    0.807000
# 7    0.728000
# 8    0.024000
# 9    0.205794
# Name: libdem_vdem_owid_replacemean, dtype: float64

# %%
countries_df['libdem_vdem_owid'].mean()
# Out:
# 0.20579428571428574

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 45 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Entity                                                182 non-null    object
#  1   indiv_libs_vdem_owid                                  177 non-null    float64
#  2   electdem_vdem_owid                                    177 non-null    float64
#  3   libdem_vdem_owid                                      175 non-null    float64
#  4   Countries                                             165 non-null    object
#  5   Economic.Freedom.Summary.Index                        182 non-null    float64
#  6   Government.consumption                                182 non-null    float64
#  7   Transfers.and.subsidies                               182 non-null    float64
# ...

# %%
working_column = 'Government.investment '
for column in range(0,(countries_df.shape[1])):
     if working_column in countries_df:
            for row in range(0, (countries_df.shape[0])):
                print(countries_df.iloc[row][working_column])
                if countries_df.iloc[row][working_column] > 9:
                     print("large value detected")
                 
                    
                    
#contents = DF.iloc[row][column]

# %%
#working_column = 0
for column in range(0,(countries_df.shape[1])):
     if type (countries_df.iloc[0][column] == np.float64
            for row in range(0, (countries_df.shape[0])):
                if countries_df.iloc[row][column] > 9:
                     #print("unusual value detected at "+str(row)+","str(column)")
                      print(f"unusual value detected at {row},{column}"")
# Out:
#   Cell In[122], line 7
#     print(f"unusual value detected at {row},{column}"")
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
def check_for_unusual_values(df)
for column in range(0,(countries_df.shape[1])):
     if type (countries_df.iloc[0][column] == np.float64
            for row in range(0, (countries_df.shape[0])):
                if countries_df.iloc[row][column] > 9:
                     #print("unusual value detected at "+str(row)+","str(column)")
                      print(f"unusual value detected at {row},{column}"")
# Out:
#   Cell In[122], line 7
#     print(f"unusual value detected at {row},{column}"")
#                                                      ^
# SyntaxError: unterminated string literal (detected at line 7)

# %%
  #  update the cell in pandas df
  df.loc[row, [column]] = value



#one way to iterate through a dataframe

 #first establish the first column to iterate through
    working_column = [name]
    #Have for loop that goes through all the columns
    for column in range(0,(df.shape[1])):
    #check if the column exists
        if working_column in df:
    #THEN go into for loop going down through all rows in that column
            for row in range(0, (df.shape[0])):

#get cell contents

contents = DF.iloc[row][column]
# Out:
#   Cell In[69], line 9
#     working_column = [name]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # lamda function

# %%
# how to use lamda function #

#df['new_column'] = df['existing_column'].apply(lambda argument: expression)
data = {'price': [100, 200, 150, 300]}
df = pd.DataFrame(data)
# Apply a lambda function to calculate discounted price
df['new_price'] = df['price'].apply(lambda x: x * 0.9)

# %%
# how to use lamda function #

df
# Out:
#    price  new_price
# 0    100       90.0
# 1    200      180.0
# 2    150      135.0
# 3    300      270.0

# %%
data = {'price': [100, 200, 150, 300]}
df = pd.DataFrame(data)
df['new_price'] = df['price'].apply('price' * 0.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 data = {'price': [100, 200, 150, 300]}
#       2 df = pd.DataFrame(data)
# ----> 3 df['new_price'] = df['price'].apply('price' * 0.9)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

condition1 = df['A'] < 3
function1 = lambda x: x * 2
condition2 = df['A'] >= 3
function2 = lambda x: x + 5

df['C'] = np.where(condition1, function1(df['B']), function2(df['B']))

print(df)
# Out:
#    A   B   C
# 0  1  10  20
# 1  2  20  40
# 2  3  30  35
# 3  4  40  45
# 4  5  50  55

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)
# Define the conditions and corresponding functions/logic
condition1 = df['A'] < 3
function1 = lambda x: x * 2
condition2 = df['A'] >= 3
function2 = lambda x: x + 5
# Apply the functions/logic based on conditions and create the new column
df['C'] = np.where(condition1,function1(df['A']),function2(df['B']))

# %%
df
# Out:
#    A   B   C
# 0  1  10   2
# 1  2  20   4
# 2  3  30  35
# 3  4  40  45
# 4  5  50  55

# %%
  #  update the cell in pandas df
  df.loc[row, [column]] = value



#one way to iterate through a dataframe

 #first establish the first column to iterate through
    working_column = [name]
    #Have for loop that goes through all the columns
    for column in range(0,(df.shape[1])):
    #check if the column exists
        if working_column in df:
    #THEN go into for loop going down through all rows in that column
            for row in range(0, (df.shape[0])):

#get cell contents

contents = DF.iloc[row][column]
# Out:
#   Cell In[75], line 9
#     working_column = [name]
#     ^
# IndentationError: unexpected indent

# %%
working_column = [name]
for column in range(0,(df.shape[1])):
     if working_column in df:
            for row in range(0, (df.shape[0])):
                
#contents = DF.iloc[row][column]

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}

# %%
df.loc[3, ['B']] = 200
df
# Out:
#    A    B   C
# 0  1   10   2
# 1  2   20   4
# 2  3   30  35
# 3  4  200  45
# 4  5   50  55

# %%
df.loc[0, ['A']] = 1000
df
# Out:
#       A    B   C
# 0  1000   10   2
# 1   700   20   4
# 2     3   30  35
# 3     4  200  45
# 4     5   50  55

# %%
df.loc[1, ['A']] = 700
df
# Out:
#       A    B   C
# 0  1000   10   2
# 1   700   20   4
# 2     3   30  35
# 3     4  200  45
# 4     5   50  55

# %%
df.iloc[3]['A']
# Out:
# 4

# %%
type(df.iloc[3]['A'])
# Out:
# numpy.int64

# %%
type(df.iloc[3]['A']) + 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 type(df.iloc[3]['A']) + 7
#
# TypeError: unsupported operand type(s) for +: 'type' and 'int'

# %%
df.iloc[3]['A']+7
# Out:
# 11

# %%
test = (df.iloc[1]['A']) #we can use [0] insted of ['A'] #
test
# Out:
# 700
